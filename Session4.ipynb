# %%
from random import uniform
from math import sqrt

class Qualean:
    
    def __init__(self,real_input):
        
        if real_input == "True":
            self.real_input = 1
        elif real_input == "False":
            self.real_input = 0
        elif real_input == "Maybe":
            self.real_input = -1
        elif real_input == -1:
            self.real_input = -1
        elif real_input == True:
            self.real_input = 1
        elif real_input == False:
            self.real_input = 0
        else:
            raise ValueError('Input can only be True, False, and Maybe or numerically (1, 0, -1)')
        
        self.input = round(uniform(-1,1) * self.real_input)
        #self.real_input = real_input
        print(self.input)
        print(self.real_input)
        
    def __repr__(self):
        return f'Qualean(real_input ={self.real_input})'
    
    def __str__(self):
        return f'Qualean(real_input ={self.real_input})'
     
    def __and__(self,other):
        if isinstance(other,self.__class__):
            return self.input and other.input
        else:
            return NotImplemented
        
    def __or__(self,other):
        if isinstance(other,self.__class__):
            return self.input or other.input
        else:
            return NotImplemented
        
          
    def __add__(self,other):
        if isinstance(other,self.__class__):
            return self.input + other.input
        else:
            return NotImplemented
        
    
    def __eq__(self,other):
        if isinstance(other,self.__class__):
            return self.input == other.input
        else:
            return NotImplemented
    
    def __ge__(self,other):
        if isinstance(other,self.__class__):
            return self.input >= other.input
        else:
            return NotImplemented
        
        
    
    def __gt__(self,other):
        if isinstance(other,self.__class__):
            return self.input > other.input
        else:
            return NotImplemented
        
    def __invertsign__(self,other):
        if self.input < 0:
            return self.input * -1
        else:
            return self.input       
        
    
    def __le__(self,other):
        if isinstance(other,self.__class__):
            return self.input <= other.input
        else:
            return NotImplemented
        
    
    def __lt__(self,other):
        if isinstance(other,self.__class__):
            return self.input < other.input
        else:
            return NotImplemented
        
    
    def __mul__(self,other):
        if isinstance(other,self.__class__):
            return self.input * other
        else:
            return NotImplemented
        
    
    def __sqrt__(self):
        if isinstance(other,self.__class__):
            return sqrt(self.input)
        else:
            return NotImplemented
